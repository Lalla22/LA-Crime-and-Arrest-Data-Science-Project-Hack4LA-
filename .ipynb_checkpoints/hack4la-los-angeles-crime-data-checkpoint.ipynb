# %%
# Importing necessary libraries
import numpy as np  # Library for numerical operations
import pandas as pd  # Library for data manipulation and analysis
import seaborn as sns  # Library for statistical data visualization
import matplotlib.pyplot as plt  # Library for creating static, animated, and interactive visualizations
from scipy.stats import norm  # Module for statistical functions and probability distributions
from sklearn.preprocessing import StandardScaler  # Module for preprocessing data
from scipy import stats  # Module for statistics and mathematical functions
import warnings  # Module for handling warnings

# Ignore warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# This part of the code is attempting to list all files under the input directory, which may not be applicable in this context

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# These comments provide information about writing data to the working directory in a Kaggle environment
# Data is provided from kaggle

# %%
# Reading the CSV file into a DataFrame
# r prefix is used for raw string literal to avoid interpreting backslashes as escape characters
# This reads the CSV file located at the specified path
df_crime = pd.read_csv(r"C:\Users\lalla\Downloads\Volunteering\Hack4LA\Hack4LA City of Los Angeles Arrests project\data sets\crime-data-from-2010-to-present.csv")

# %%
df_crime.head()
# Out:
#    DR Number        Date Reported        Date Occurred  Time Occurred  \
# 0  102005556  2010-01-25T00:00:00  2010-01-22T00:00:00         2300.0
# 1  101822289  2010-11-11T00:00:00  2010-11-10T00:00:00         1800.0
# 2  101105609  2010-01-28T00:00:00  2010-01-27T00:00:00         2230.0
# 3  101620051  2010-11-11T00:00:00  2010-11-07T00:00:00         1600.0
# 4  101910498  2010-04-07T00:00:00  2010-04-07T00:00:00         1600.0
#
#    Area ID  Area Name  Reporting District  Crime Code Crime Code Description  \
# 0     20.0    Olympic              2071.0       510.0       VEHICLE - STOLEN
# 1     18.0  Southeast              1803.0       510.0       VEHICLE - STOLEN
# 2     11.0  Northeast              1125.0       510.0       VEHICLE - STOLEN
# 3     16.0   Foothill              1641.0       510.0       VEHICLE - STOLEN
# 4     19.0    Mission              1902.0       510.0       VEHICLE - STOLEN
#
#   MO Codes  ...  Unnamed: 26 Unnamed: 27 Unnamed: 28  Unnamed: 29 Unnamed: 30  \
# ...

# %%
df_crime.shape
# Out:
# (82, 36)

# %%
df_crime.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location ', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35'],
#       dtype='object')

# %%
df_crime.columns = [c.replace(' ', '_') for c in df_crime.columns]

# %%
df_crime['Area_Name'].describe()
# Out:
# count         66
# unique        14
# top       Newton
# freq          17
# Name: Area_Name, dtype: object

# %%
df_crime['Crime_Code'].describe()
# Out:
# count     62.000000
# mean     488.193548
# std      139.801831
# min        1.000000
# 25%      510.000000
# 50%      510.000000
# 75%      510.000000
# max      946.000000
# Name: Crime_Code, dtype: float64

# %%
df_crime['Crime_Code_Description'].head()
# Out:
# 0    VEHICLE - STOLEN
# 1    VEHICLE - STOLEN
# 2    VEHICLE - STOLEN
# 3    VEHICLE - STOLEN
# 4    VEHICLE - STOLEN
# Name: Crime_Code_Description, dtype: object

# %%
df_crime.describe()
# Out:
#        Time_Occurred    Area_ID  Reporting_District  Crime_Code  Victim_Age  \
# count      67.000000  68.000000           62.000000   62.000000   62.000000
# mean     1531.402985  12.750000         1423.870968  488.193548    2.596774
# std       686.931210   5.198665          417.501918  139.801831    8.633635
# min         1.000000   1.000000            1.000000    1.000000    0.000000
# 25%      1200.000000  12.000000         1276.250000  510.000000    0.000000
# 50%      1700.000000  13.000000         1383.000000  510.000000    0.000000
# 75%      2022.500000  16.000000         1659.000000  510.000000    0.000000
# max      2340.000000  21.000000         2143.000000  946.000000   43.000000
#
#        Premise_Code  Weapon_Used_Code  Weapon_Description  Crime_Code_1  \
# count     62.000000          3.000000            3.000000     62.000000
# mean      96.838710          0.333333            0.333333    488.193548
# ...

# %%
df_crime.Victim_Age.mean()
# Out:
# 2.596774193548387

# %%
df_crime.DR_Number.count()
# Out:
# 80

# %%
df_crime.Area_Name.value_counts()
# Out:
# Newton         17
# Southeast       6
# Northeast       6
# Foothill        6
# 77th Street     6
# Pacific         5
# 2               5
# Mission         4
# N Hollywood     3
# Devonshire      3
# 11              2
# Olympic         1
# West Valley     1
# Topanga         1
# Name: Area_Name, dtype: int64

# %%
df_crime.Address.value_counts()
# Out:
# SAN FERNANDO                               2
# EL DORADO                                  2
# 21ST                                       2
# 59TH                                       2
# HORIZON                                    1
# CULVER                                     1
# 6300 W  80TH                         ST    1
# VALERIO                                    1
# OLYMPIC                                    1
# MAGNOLIA                                   1
# VARNA                                      1
# DE FOE                                     1
# REMICK                                     1
# LAUREL CANYON                              1
# BRYNHURST                                  1
# MOSS                                       1
# VAN NESS                                   1
# RINALDI                                    1
# VICTORY                                    1
# VICKSBURG                                  1
# HASKELL                                    1
# ...

# %%
df_crime.Crime_Code_Description.value_counts()
# Out:
# VEHICLE - STOLEN             52
# 2                             5
# BURGLARY FROM VEHICLE         4
# INDECENT EXPOSURE             1
# OTHER ASSAULT                 1
# OTHER MISCELLANEOUS CRIME     1
# 25                            1
# 16                            1
# Name: Crime_Code_Description, dtype: int64

# %%
df_crime.Weapon_Description.value_counts()
# Out:
# 0.0    2
# 1.0    1
# Name: Weapon_Description, dtype: int64

# %%
df_crime.Weapon_Used_Code.value_counts()
# Out:
# 0.0    2
# 1.0    1
# Name: Weapon_Used_Code, dtype: int64

# %%
df_crime.Area_Name.unique()
# Out:
# array(['Olympic', 'Southeast', 'Northeast', 'Foothill', 'Mission',
#        'Newton', 'West Valley', '77th Street', 'Pacific', 'N Hollywood',
#        'Topanga', 'Devonshire', nan, '2', '11'], dtype=object)

# %%
# Histogram with KDE for 'Victim Age' column
plt.figure(figsize=(10, 6))
sns.histplot(df_crime['Victim_Age'], kde=True, bins=30, color='blue')
plt.title('Distribution of Age')
plt.xlabel('Victim Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram with KDE for 'Victim Sex' column
plt.figure(figsize=(10, 6))
sns.histplot(df_crime['Victim_Sex'], kde=True, bins=30, color='blue')
plt.title('Distribution of Age')
plt.xlabel('Victim Sex')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram with KDE for 'Victim Age' column
plt.figure(figsize=(10, 6))
sns.histplot(df_crime['Victim_Age'], kde=True, bins=30, color='blue')
plt.title('Distribution of Age')
plt.xlabel('Victim Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar plot for top 10 'Crime_Code_Description'
top_charge_groups = df_crime['Crime_Code_Description'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_charge_groups.values, y=top_charge_groups.index, palette='viridis')
plt.title('Top 10 Charge Groups')
plt.xlabel('Count')
plt.ylabel('Crime Group Description')
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = df_crime.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
#Histogram 
sns.distplot(df_crime['Victim_Age'])
# Out:
# C:\Users\lalla\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Victim_Age', ylabel='Density'>

# %%
# Histogram and KDE plot of time crime happened
plt.figure(figsize=(10, 6))
sns.histplot(df_crime['Time_Occurred'], kde=True, color='blue')
plt.title('Distribution of Time')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.show()

# %%
#Skewness and Kurtosis

# %%
#Box Plot

# %%
# Correlation Matrix

# %%
# Correlation Matrix
